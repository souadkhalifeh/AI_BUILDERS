# %% [markdown]
# # Matplotlib Exercises — Heart Disease Dataset
#
# Practise data visualization with **matplotlib** on the heart-disease dataset (303 patients).
#
# You'll create line, scatter, histogram, and bar charts, customise them with titles/labels/legends, and arrange multiple plots with subplots.
#
# **The columns:**
#
# | Column | Meaning |
# |---|---|
# | `age` | Age in years |
# | `sex` | 0 = female, 1 = male |
# | `cp` | Chest pain type (0–3) |
# | `trestbps` | Resting blood pressure |
# | `chol` | Serum cholesterol (mg/dl) |
# | `fbs` | Fasting blood sugar > 120 mg/dl (1 = true) |
# | `thalach` | Maximum heart rate achieved |
# | `exang` | Exercise-induced angina (1 = yes) |
# | `oldpeak` | ST depression induced by exercise |
# | `target` | 1 = has heart disease, 0 = no heart disease |
#
# **Instructions:** Solve each exercise in the empty cell below its prompt. Full answers will be shared after you're done — try each one yourself first.
#
# > Tip: put `%matplotlib inline` at the top so plots show inside the notebook.

# %% [markdown]
# ## 0. Setup

# %% [markdown]
# **Exercise 0.** Import `matplotlib.pyplot` as `plt` and `pandas` as `pd`, enable inline plotting, and read `../data/heart-disease.csv` into a DataFrame called `df`. Show the first 5 rows.

# %%
# Your code here

# %% [markdown]
# ## 1. Line and Scatter Plots

# %% [markdown]
# **Exercise 1.** Using the object-oriented interface (`fig, ax = plt.subplots()`), make a **scatter plot** of `age` (x-axis) vs `chol` (y-axis). Add a title "Age vs Cholesterol" and axis labels.

# %%
# Your code here

# %% [markdown]
# **Exercise 2.** Make a scatter plot of `age` (x) vs `thalach` (max heart rate, y), and **colour the points by `target`** so diseased and healthy patients are distinguishable. Add a colorbar.

# %%
# Your code here

# %% [markdown]
# ## 2. Histograms

# %% [markdown]
# **Exercise 3.** Plot a **histogram** of the `age` column with 20 bins. Add a title and label the axes.

# %%
# Your code here

# %% [markdown]
# **Exercise 4.** Plot **two histograms of `thalach`** on the same axes — one for patients **with** heart disease (`target == 1`) and one for those **without** (`target == 0`). Use `alpha=0.5` so they overlap visibly, and add a legend.

# %%
# Your code here

# %% [markdown]
# ## 3. Bar Charts

# %% [markdown]
# **Exercise 5.** Make a **bar chart** showing how many patients have heart disease vs not. (Hint: `df["target"].value_counts()`.) Label the two bars "No disease" and "Disease".

# %%
# Your code here

# %% [markdown]
# **Exercise 6.** Make a bar chart of the **count of each chest pain type** (`cp`, values 0–3), sorted by chest pain type on the x-axis.

# %%
# Your code here

# %% [markdown]
# **Exercise 7.** Compute the **average cholesterol by sex** (group by `sex`, mean of `chol`) and show it as a bar chart with the bars labelled "Female" and "Male".

# %%
# Your code here

# %% [markdown]
# ## 4. Subplots

# %% [markdown]
# **Exercise 8.** Create a figure with a **2×2 grid of subplots** (`figsize=(10, 8)`) showing four different views of the data:
#
# - top-left: histogram of `age`
# - top-right: histogram of `chol`
# - bottom-left: scatter of `age` vs `thalach`
# - bottom-right: bar chart of `target` counts
#
# Give each subplot its own title, and call `fig.tight_layout()` at the end so they don't overlap.

# %%
# Your code here

# %% [markdown]
# ## 5. Styling and Saving

# %% [markdown]
# **Exercise 9.** Apply a built-in style (e.g. `plt.style.use("seaborn-v0_8")` or `"ggplot"`), then redraw the `age` vs `thalach` scatter coloured by `target`. (You can list available styles with `plt.style.available`.)

# %%
# Your code here

# %% [markdown]
# **Exercise 10.** Build any plot you like from the data, then **save the figure** to a file called `heart-plot.png` using `fig.savefig(...)`.

# %%
# Your code here

# %% [markdown]
# ## 🏆 Challenge Exercises
#
# 1. Make a **grouped bar chart** comparing the number of healthy vs diseased patients **for each sex** (4 bars total, or two bars per sex side-by-side).
# 2. Plot the **mean `thalach` by age group**: bin `age` into ranges (e.g. with `pd.cut`) and draw a line or bar chart of the average max heart rate per group.
# 3. Recreate the Exercise 8 dashboard but add a shared figure title with `fig.suptitle(...)`.

# %%
# Your challenge code here
